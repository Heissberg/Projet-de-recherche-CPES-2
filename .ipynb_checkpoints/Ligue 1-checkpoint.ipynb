# %%
import os
import pandas as pd
import glob
import random
import numpy as np
import matplotlib.pyplot as plt
import csv
import seaborn as sns

# %%
data = pd.read_csv('ligue1_2019.csv',index_col='Date',parse_dates=True)

# %%
data.head()
# Out:
#            Div     HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# Date
# 2018-10-08  F1    Marseille  Toulouse     4     0   H     1     0   H  23
# 2018-11-08  F1       Angers     Nimes     3     4   A     1     1   D  21
# 2018-11-08  F1        Lille    Rennes     3     1   H     1     1   D  15
# 2018-11-08  F1  Montpellier     Dijon     1     2   A     1     0   H  16
# 2018-11-08  F1       Nantes    Monaco     1     3   A     0     0   D  16
#
#             ...  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
# Date        ...
# 2018-10-08  ...      2.11    18  -1.25     2.05     1.98     1.91     1.87
# 2018-11-08  ...      1.66    20  -0.25     1.99     1.95     1.94     1.90
# 2018-11-08  ...      1.64    20   0.00     1.82     1.77     2.15     2.09
# 2018-11-08  ...      1.71    20  -1.00     2.45     2.32     1.67     1.61
# 2018-11-08  ...      1.74    20   0.25     1.90     1.85     2.06     2.01
#
#             PSCH  PSCD  PSCA
# Date
# ...

# %%
data = data.drop(data.columns[21:],axis = 1)

# %%
data = data.drop('Div',axis = 1)

# %%
data.columns
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR',
#        'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR',
#        'AR'],
#       dtype='object')

# %%
data
# Out:
#                HomeTeam    AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG  HTR  HS  AS  \
# Date
# 2018-10-08    Marseille    Toulouse     4     0    1     1     0    1  23   5
# 2018-11-08       Angers       Nimes     3     4   -1     1     1    0  21  14
# 2018-11-08        Lille      Rennes     3     1    1     1     1    0  15   8
# 2018-11-08  Montpellier       Dijon     1     2   -1     1     0    1  16   9
# 2018-11-08       Nantes      Monaco     1     3   -1     0     0    0  16  11
# ...                 ...         ...   ...   ...  ...   ...   ...  ...  ..  ..
# 2019-05-24       Nantes  Strasbourg     0     1   -1     0     0    0  21   5
# 2019-05-24         Nice      Monaco     2     0    1     1     0    1   8  11
# 2019-05-24        Nimes        Lyon     2     3   -1     2     1    1  17  19
# 2019-05-24        Reims    Paris SG     3     1    1     1     0    1  10  13
# 2019-05-24       Rennes       Lille     3     1    1     1     1    0  13  14
#
# ...

# %%
#encodage du resultat à la mi temps
data.loc[:,'HTR'] = data.loc[:,'HTR'].map({'H':1,'D':0,'A':-1})

# %%
#Encodage du resultat de fin de match
data.loc[:,'FTR'] = data.loc[:,'FTR'].map({'H':1,'D':0,'A':-1})

# %%
equipes = data.HomeTeam.unique()

# %%
equipes
# Out:
# array(['Marseille', 'Angers', 'Lille', 'Montpellier', 'Nantes', 'Nice',
#        'St Etienne', 'Bordeaux', 'Lyon', 'Paris SG', 'Reims', 'Amiens',
#        'Caen', 'Dijon', 'Guingamp', 'Monaco', 'Rennes', 'Nimes',
#        'Strasbourg', 'Toulouse'], dtype=object)

# %%
n_matchs_MS = {}
for i in equipes:
    n_matchs_MS[i] = len(data[data['HomeTeam']==i].loc['2018'] + data[data['AwayTeam']==i].loc['2018'])
    
matchs_manquants = {}
for i in equipes:
    if n_matchs_MS[i]<19:
        l = list(equipes)
        l.remove(i)
        for j in data[data['HomeTeam']==i].loc['2018']['AwayTeam']:
            l.remove(j)
        for j in data[data['AwayTeam']==i].loc['2018']['HomeTeam']:
            l.remove(j)
        matchs_manquants[i] = l

# %%
X_train = data.loc['2018']
X_test = data.loc['2019']

# %%
for i in matchs_manquants.keys():
    for j in matchs_manquants[i]:
        match_manquant = data[(data['HomeTeam']==i) & (data['AwayTeam']==j)]
        X_train = X_train.append(match_manquant)
        matchs_manquants[i].remove(j)
        matchs_manquants[j].remove(i)

# %%
domicile = X_train.groupby('HomeTeam')[['FTHG','FTAG','FTR']].mean()
exterieur = X_train.groupby('AwayTeam')[['FTAG','FTHG','FTR']].mean()
print(domicile,exterieur)
# Out:
#                  FTHG      FTAG       FTR
# HomeTeam
# Amiens       1.333333  1.555556 -0.222222
# Angers       1.100000  1.300000 -0.200000
# Bordeaux     1.545455  1.090909  0.272727
# Caen         1.111111  1.222222 -0.111111
# Dijon        0.666667  2.111111 -0.444444
# Guingamp     1.111111  1.888889 -0.444444
# Lille        1.900000  0.800000  0.500000
# Lyon         1.909091  0.727273  0.454545
# Marseille    2.111111  0.666667  0.555556
# Monaco       0.777778  1.888889 -0.666667
# Montpellier  1.363636  0.727273  0.181818
# Nantes       2.000000  1.444444  0.000000
# Nice         0.800000  1.100000  0.000000
# Nimes        1.375000  1.250000 -0.125000
# Paris SG     3.300000  0.400000  1.000000
# Reims        0.900000  0.700000  0.200000
# Rennes       1.444444  1.222222  0.111111
# St Etienne   2.111111  0.666667  0.777778
# Strasbourg   1.700000  1.100000  0.200000
# Toulouse     1.125000  1.500000 -0.125000                  FTAG      FTHG       FTR
# AwayTeam
# ...

# %%
def categorie_resultat(FTR):
    if FTR <= -0.5:
        return(0)
    elif (FTR>-0.5)&(FTR<=0):
        return(1)
    elif (FTR<=0.5)&(FTR>0):
        return(2)
    else:
        return(3)

for i in equipes:
    domicile.loc[i,'FTR'] = categorie_resultat(domicile.loc[i,'FTR'])
    exterieur.loc[i,'FTR'] = categorie_resultat(exterieur.loc[i,'FTR'])

# %%
sns.catplot(x = 'FTHG', y = 'FTAG', data = domicile,hue = 'FTR')
sns.catplot(x = 'FTHG', y = 'FTAG', data = exterieur,hue = 'FTR')

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
model = LogisticRegressionCV()
model.fit(domicile.drop('FTR',axis = 1),domicile.loc[:,'FTR'])
# Out:
# /Users/andreassimatos/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# /Users/andreassimatos/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/andreassimatos/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
